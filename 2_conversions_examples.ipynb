# %%
a = 0b10111
print(a)
print(type(a))
# Out:
# 23
# <class 'int'>

# %%
a = 0b11001
print(a)
# Out:
# 25

# %%
a = 0b111111
print(a)
# Out:
# 63

# %%
a = 0b100101
print(a)
# Out:
# 37

# %%
a = 0b1011010
print(a)
# Out:
# 90

# %%
a = 0o17
print(a)
# Out:
# 15

# %%
a = 0o25
print(a)
# Out:
# 21

# %%
a = 0o76
print(a)
# Out:
# 62

# %%
a = 0o123
print(a)
# Out:
# 83

# %%
a = 0o345
print(a)
# Out:
# 229

# %%
a = 0x1B
print(a)
# Out:
# 27

# %%
a = 0x2F
print(a)
# Out:
# 47

# %%
a = 0xAC
print(a)
# Out:
# 172

# %%
a = 0x1D4
print(a)
# Out:
# 468

# %%
a = 0x3e8
print(a)
# Out:
# 1000
